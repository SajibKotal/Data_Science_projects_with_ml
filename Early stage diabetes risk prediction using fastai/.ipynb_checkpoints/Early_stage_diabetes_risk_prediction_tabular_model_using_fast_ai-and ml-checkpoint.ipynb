# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install -Uqq fastbook
import fastbook
#fastbook.setup_book()

# %%
from fastbook import *
from fastai.tabular.all import *

path=Path('/content/drive/MyDrive/Fast ai')
path
# Out:
# Path('/content/drive/MyDrive/Fast ai')

# %%
df=pd.read_csv(path/'diabetes_data_upload.csv', low_memory=False)

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Polyuria', 'Polydipsia', 'sudden weight loss',
#        'weakness', 'Polyphagia', 'Genital thrush', 'visual blurring',
#        'Itching', 'Irritability', 'delayed healing', 'partial paresis',
#        'muscle stiffness', 'Alopecia', 'Obesity', 'class'],
#       dtype='object')

# %%
df.head()
# Out:
#    Age Gender Polyuria Polydipsia sudden weight loss weakness Polyphagia  \
# 0   40   Male       No        Yes                 No      Yes         No
# 1   58   Male       No         No                 No      Yes         No
# 2   41   Male      Yes         No                 No      Yes        Yes
# 3   45   Male       No         No                Yes      Yes        Yes
# 4   60   Male      Yes        Yes                Yes      Yes        Yes
#
#   Genital thrush visual blurring Itching Irritability delayed healing  \
# 0             No              No     Yes           No             Yes
# 1             No             Yes      No           No              No
# 2             No              No     Yes           No             Yes
# 3            Yes              No     Yes           No             Yes
# 4             No             Yes     Yes          Yes             Yes
#
#   partial paresis muscle stiffness Alopecia Obesity     class
# 0              No              Yes      Yes     Yes  Positive
# 1             Yes               No      Yes      No  Positive
# 2              No              Yes      Yes      No  Positive
# 3              No               No       No      No  Positive
# 4             Yes              Yes      Yes     Yes  Positive

# %%
df.tail()
# Out:
#      Age  Gender Polyuria Polydipsia sudden weight loss weakness Polyphagia  \
# 515   39  Female      Yes        Yes                Yes       No        Yes
# 516   48  Female      Yes        Yes                Yes      Yes        Yes
# 517   58  Female      Yes        Yes                Yes      Yes        Yes
# 518   32  Female       No         No                 No      Yes         No
# 519   42    Male       No         No                 No       No         No
#
#     Genital thrush visual blurring Itching Irritability delayed healing  \
# 515             No              No     Yes           No             Yes
# 516             No              No     Yes          Yes             Yes
# 517             No             Yes      No           No              No
# 518             No             Yes     Yes           No             Yes
# 519             No              No      No           No              No
#
#     partial paresis muscle stiffness Alopecia Obesity     class
# 515             Yes               No       No      No  Positive
# 516             Yes               No       No      No  Positive
# 517             Yes              Yes       No     Yes  Positive
# 518              No               No      Yes      No  Negative
# 519              No               No       No      No  Negative

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 520 entries, 0 to 519
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Age                 520 non-null    int64
#  1   Gender              520 non-null    object
#  2   Polyuria            520 non-null    object
#  3   Polydipsia          520 non-null    object
#  4   sudden weight loss  520 non-null    object
#  5   weakness            520 non-null    object
#  6   Polyphagia          520 non-null    object
#  7   Genital thrush      520 non-null    object
#  8   visual blurring     520 non-null    object
#  9   Itching             520 non-null    object
#  10  Irritability        520 non-null    object
#  11  delayed healing     520 non-null    object
#  12  partial paresis     520 non-null    object
#  13  muscle stiffness    520 non-null    object
#  14  Alopecia            520 non-null    object
#  15  Obesity             520 non-null    object
#  16  class               520 non-null    object
# dtypes: int64(1), object(16)
# memory usage: 69.2+ KB

# %%
#Checking for null values
df.isnull().sum()
# Out:
# Age                   0
# Gender                0
# Polyuria              0
# Polydipsia            0
# sudden weight loss    0
# weakness              0
# Polyphagia            0
# Genital thrush        0
# visual blurring       0
# Itching               0
# Irritability          0
# delayed healing       0
# partial paresis       0
# muscle stiffness      0
# Alopecia              0
# Obesity               0
# class                 0
# dtype: int64

# %%
df['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df['class'].unique()
# Out:
# array(['Positive', 'Negative'], dtype=object)

# %%
df['Age'].unique()
# Out:
# array([40, 58, 41, 45, 60, 55, 57, 66, 67, 70, 44, 38, 35, 61, 54, 43, 62, 39, 48, 32, 42, 52, 53, 37, 49, 63, 30, 50, 46, 36, 51, 59, 65, 25, 47, 28, 68, 56, 31, 85, 90, 72, 69, 79, 34, 16, 33, 64,
#        27, 29, 26])

# %%
df['weakness'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %% [markdown]
# Categorify is a TabularProc that replaces a column with a numeric categorical column. FillMissing is a TabularProc that replaces missing values with the median of the column, and creates a new Boolean column that is set to True for any row where the value was missing. These two transforms are needed for nearly every tabular dataset you will use, so this is a good starting point for your data processing:

# %%
procs = [Categorify, FillMissing, Normalize]

# %%
#df['Gender'] = df['Gender'].astype('category')
#df['Gender'].cat.set_categories(df['Gender'].unique(), ordered=False, inplace=True)

# %%
#https://docs.fast.ai/tutorial.tabular.html
dls=TabularDataLoaders.from_csv(path/'diabetes_data_upload.csv', path=path,
                                y_names='class', #label column
                               cat_names = ['Gender','Polyuria','Polydipsia','sudden weight loss','weakness','Polyphagia','Genital thrush','visual blurring','Itching','Irritability','delayed healing','partial paresis','muscle stiffness','Alopecia','Obesity'], #category columns
                               cont_names=['Age'],#continuous columns
                               procs=procs)

#If you get error message: TypeError: Categorical cannot perform the operation median,
#it is most likely that you have one categorical variable flagged as continuous.
#So when it tried to find its median value during FillMissing, it throws an error (sgugger,forum.fast.ai, 2018).

# %%
#The show_batch method works like for every other application:
dls.show_batch()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Gender</th>
#       <th>Polyuria</th>
#       <th>Polydipsia</th>
#       <th>sudden weight loss</th>
#       <th>weakness</th>
#       <th>Polyphagia</th>
#       <th>Genital thrush</th>
#       <th>visual blurring</th>
#       <th>Itching</th>
#       <th>Irritability</th>
#       <th>delayed healing</th>
#       <th>partial paresis</th>
#       <th>muscle stiffness</th>
#       <th>Alopecia</th>
#       <th>Obesity</th>
#       <th>Age</th>
#       <th>class</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Female</td>
#       <td>Yes</td>
#       <td>Yes</td>
#       <td>Yes</td>
#       <td>Yes</td>
#       <td>Yes</td>
#       <td>No</td>
#       <td>No</td>
#       <td>Yes</td>
#       <td>No</td>
#       <td>Yes</td>
#       <td>Yes</td>
#       <td>Yes</td>
#       <td>No</td>
#       <td>No</td>
#       <td>35.000000</td>
#       <td>Positive</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Female</td>
#       <td>No</td>
#       <td>No</td>
#       <td>No</td>
#       <td>No</td>
#       <td>Yes</td>
#       <td>No</td>
#       <td>Yes</td>
#       <td>Yes</td>
#       <td>No</td>
#       <td>No</td>
#       <td>Yes</td>
#       <td>No</td>
#       <td>No</td>
#       <td>No</td>
#       <td>45.000000</td>
#       <td>Positive</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Female</td>
#       <td>Yes</td>
#       <td>Yes</td>
#       <td>Yes</td>
#       <td>Yes</td>
#       <td>Yes</td>
#       <td>No</td>
#       <td>No</td>
#       <td>No</td>
#       <td>No</td>
#       <td>No</td>
#       <td>Yes</td>
#       <td>No</td>
#       <td>No</td>
#       <td>No</td>
#       <td>54.000000</td>
#       <td>Positive</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Female</td>
#       <td>Yes</td>
#       <td>Yes</td>
#       <td>Yes</td>
#       <td>Yes</td>
#       <td>No</td>
#       <td>No</td>
#       <td>Yes</td>
#       <td>No</td>
#       <td>No</td>
#       <td>Yes</td>
#       <td>Yes</td>
#       <td>Yes</td>
#       <td>No</td>
#       <td>No</td>
#       <td>40.000000</td>
#       <td>Positive</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Male</td>
#       <td>No</td>
#       <td>No</td>
#       <td>No</td>
#       <td>Yes</td>
#       <td>No</td>
#       <td>No</td>
#       <td>No</td>
#       <td>Yes</td>
#       <td>No</td>
#       <td>Yes</td>
#       <td>No</td>
#       <td>Yes</td>
#       <td>Yes</td>
#       <td>No</td>
#       <td>54.000000</td>
#       <td>Negative</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Female</td>
#       <td>Yes</td>
#       <td>Yes</td>
#       <td>Yes</td>
#       <td>Yes</td>
#       <td>No</td>
#       <td>No</td>
#       <td>Yes</td>
#       <td>No</td>
#       <td>No</td>
#       <td>Yes</td>
#       <td>Yes</td>
#       <td>Yes</td>
#       <td>No</td>
#       <td>No</td>
#       <td>40.000000</td>
#       <td>Positive</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Male</td>
#       <td>No</td>
#       <td>No</td>
#       <td>No</td>
#       <td>No</td>
#       <td>No</td>
#       <td>No</td>
#       <td>No</td>
#       <td>No</td>
#       <td>No</td>
#       <td>No</td>
#       <td>No</td>
#       <td>No</td>
#       <td>No</td>
#       <td>No</td>
#       <td>29.999999</td>
#       <td>Negative</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Female</td>
#       <td>Yes</td>
#       <td>Yes</td>
#       <td>Yes</td>
#       <td>Yes</td>
#       <td>Yes</td>
#       <td>No</td>
#       <td>Yes</td>
#       <td>Yes</td>
#       <td>Yes</td>
#       <td>Yes</td>
#       <td>Yes</td>
#       <td>Yes</td>
#       <td>No</td>
#       <td>No</td>
#       <td>48.000000</td>
#       <td>Positive</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Female</td>
#       <td>No</td>
#       <td>No</td>
#       <td>Yes</td>
#       <td>Yes</td>
#       <td>Yes</td>
#       <td>No</td>
#       <td>No</td>
#       <td>No</td>
#       <td>No</td>
#       <td>No</td>
#       <td>No</td>
#       <td>Yes</td>
#       <td>No</td>
#       <td>No</td>
#       <td>47.000000</td>
#       <td>Positive</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Male</td>
#       <td>No</td>
#       <td>Yes</td>
#       <td>No</td>
#       <td>No</td>
#       <td>No</td>
#       <td>No</td>
#       <td>Yes</td>
#       <td>Yes</td>
#       <td>No</td>
#       <td>No</td>
#       <td>No</td>
#       <td>Yes</td>
#       <td>No</td>
#       <td>No</td>
#       <td>58.000000</td>
#       <td>Negative</td>
#     </tr>
#   </tbody>
# </table>

# %%
#splits=RandomSplitter(valid_pct=0.2)

# %%
splits = RandomSplitter(valid_pct=0.2)(range_of(df))

# %%
to = TabularPandas(df, procs=[Categorify, FillMissing,Normalize],
                   cat_names = ['Gender','Polyuria','Polydipsia','sudden weight loss','weakness','Polyphagia','Genital thrush','visual blurring','Itching','Irritability','delayed healing','partial paresis','muscle stiffness','Alopecia','Obesity'],
                   cont_names = ['Age'],
                   y_names='class',
                   splits=splits)

# %%
to.xs.iloc[:2]
# Out:
#      Gender  Polyuria  Polydipsia  sudden weight loss  weakness  Polyphagia  \
# 116       1         2           2                   2         1           2
# 236       2         1           1                   1         2           2
#
#      Genital thrush  visual blurring  Itching  Irritability  delayed healing  \
# 116               1                1        1             2                1
# 236               1                2        2             1                2
#
#      partial paresis  muscle stiffness  Alopecia  Obesity       Age
# 116                2                 2         1        1 -1.501026
# 236                1                 2         2        1  0.967064

# %%
#dls.xs.iloc[:2]
# Out:
#     Gender  Polyuria  Polydipsia  sudden weight loss  weakness  Polyphagia  \
# 92       1         2           2                   2         2           1
# 1        2         1           1                   1         2           1
#
#     Genital thrush  visual blurring  Itching  Irritability  delayed healing  \
# 92               1                2        1             1                2
# 1                1                2        1             1                1
#
#     partial paresis  muscle stiffness  Alopecia  Obesity       Age
# 92                2                 2         1        1 -0.654612
# 1                 2                 1         2        1  0.896569

# %%
dls = to.dataloaders(bs=64)

# %%
dls.show_batch()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Gender</th>
#       <th>Polyuria</th>
#       <th>Polydipsia</th>
#       <th>sudden weight loss</th>
#       <th>weakness</th>
#       <th>Polyphagia</th>
#       <th>Genital thrush</th>
#       <th>visual blurring</th>
#       <th>Itching</th>
#       <th>Irritability</th>
#       <th>delayed healing</th>
#       <th>partial paresis</th>
#       <th>muscle stiffness</th>
#       <th>Alopecia</th>
#       <th>Obesity</th>
#       <th>Age</th>
#       <th>class</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Male</td>
#       <td>No</td>
#       <td>No</td>
#       <td>No</td>
#       <td>No</td>
#       <td>Yes</td>
#       <td>Yes</td>
#       <td>No</td>
#       <td>No</td>
#       <td>No</td>
#       <td>No</td>
#       <td>No</td>
#       <td>No</td>
#       <td>No</td>
#       <td>No</td>
#       <td>45.0</td>
#       <td>Negative</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Male</td>
#       <td>No</td>
#       <td>No</td>
#       <td>No</td>
#       <td>No</td>
#       <td>No</td>
#       <td>No</td>
#       <td>No</td>
#       <td>No</td>
#       <td>No</td>
#       <td>No</td>
#       <td>No</td>
#       <td>No</td>
#       <td>No</td>
#       <td>No</td>
#       <td>38.0</td>
#       <td>Negative</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Male</td>
#       <td>No</td>
#       <td>No</td>
#       <td>No</td>
#       <td>Yes</td>
#       <td>No</td>
#       <td>No</td>
#       <td>Yes</td>
#       <td>No</td>
#       <td>No</td>
#       <td>No</td>
#       <td>Yes</td>
#       <td>No</td>
#       <td>Yes</td>
#       <td>No</td>
#       <td>58.0</td>
#       <td>Positive</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Female</td>
#       <td>Yes</td>
#       <td>Yes</td>
#       <td>Yes</td>
#       <td>Yes</td>
#       <td>Yes</td>
#       <td>No</td>
#       <td>Yes</td>
#       <td>Yes</td>
#       <td>Yes</td>
#       <td>Yes</td>
#       <td>Yes</td>
#       <td>No</td>
#       <td>No</td>
#       <td>No</td>
#       <td>45.0</td>
#       <td>Positive</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Female</td>
#       <td>No</td>
#       <td>No</td>
#       <td>No</td>
#       <td>No</td>
#       <td>Yes</td>
#       <td>No</td>
#       <td>Yes</td>
#       <td>No</td>
#       <td>No</td>
#       <td>No</td>
#       <td>Yes</td>
#       <td>No</td>
#       <td>No</td>
#       <td>No</td>
#       <td>53.0</td>
#       <td>Positive</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Female</td>
#       <td>Yes</td>
#       <td>Yes</td>
#       <td>Yes</td>
#       <td>Yes</td>
#       <td>No</td>
#       <td>No</td>
#       <td>No</td>
#       <td>Yes</td>
#       <td>No</td>
#       <td>Yes</td>
#       <td>Yes</td>
#       <td>Yes</td>
#       <td>No</td>
#       <td>No</td>
#       <td>30.0</td>
#       <td>Positive</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Male</td>
#       <td>No</td>
#       <td>No</td>
#       <td>Yes</td>
#       <td>Yes</td>
#       <td>Yes</td>
#       <td>No</td>
#       <td>Yes</td>
#       <td>Yes</td>
#       <td>No</td>
#       <td>Yes</td>
#       <td>No</td>
#       <td>Yes</td>
#       <td>Yes</td>
#       <td>No</td>
#       <td>56.0</td>
#       <td>Negative</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Male</td>
#       <td>No</td>
#       <td>No</td>
#       <td>No</td>
#       <td>Yes</td>
#       <td>No</td>
#       <td>No</td>
#       <td>No</td>
#       <td>Yes</td>
#       <td>No</td>
#       <td>Yes</td>
#       <td>No</td>
#       <td>No</td>
#       <td>Yes</td>
#       <td>No</td>
#       <td>46.0</td>
#       <td>Negative</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Male</td>
#       <td>No</td>
#       <td>No</td>
#       <td>No</td>
#       <td>No</td>
#       <td>No</td>
#       <td>No</td>
#       <td>No</td>
#       <td>Yes</td>
#       <td>No</td>
#       <td>No</td>
#       <td>No</td>
#       <td>No</td>
#       <td>Yes</td>
#       <td>No</td>
#       <td>47.0</td>
#       <td>Negative</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Male</td>
#       <td>No</td>
#       <td>No</td>
#       <td>Yes</td>
#       <td>Yes</td>
#       <td>No</td>
#       <td>Yes</td>
#       <td>No</td>
#       <td>No</td>
#       <td>No</td>
#       <td>Yes</td>
#       <td>No</td>
#       <td>No</td>
#       <td>Yes</td>
#       <td>No</td>
#       <td>54.0</td>
#       <td>Negative</td>
#     </tr>
#   </tbody>
# </table>

# %%
#We can define a model using the tabular_learner method. When we define our model, fastai will try to infer the loss function based on our y_names earlier.
learn=tabular_learner(dls, metrics=accuracy)

# %%
#And we can train that model with the fit_one_cycle method (the fine_tune method won't be useful here since we don't have a pretrained model).
learn.fit_one_cycle(1)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.865867</td>
#       <td>0.679429</td>
#       <td>0.586538</td>
#       <td>00:00</td>
#     </tr>
#   </tbody>
# </table>

# %%
#We can then have a look at some predictions:
learn.show_results()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ---------------------------------------------------------------------------
# SettingWithCopyError                      Traceback (most recent call last)
# <ipython-input-75-5df3da73e23f> in <cell line: 2>()
#       1 #We can then have a look at some predictions:
# ----> 2 learn.show_results()
#
# /usr/local/lib/python3.10/dist-packages/fastai/learner.py in show_results(self, ds_idx, dl, max_n, shuffle, **kwargs)
#     332         b = dl.one_batch()
#     333         _,_,preds = self.get_preds(dl=[b], with_decoded=True)
# --> 334         dl.show_results(b, preds, max_n=max_n, **kwargs)
#     335
#     336     def show_training_loop(self):
#
# /usr/local/lib/python3.10/dist-packages/fastai/data/core.py in show_results(self, b, out, max_n, ctxs, show, **kwargs)
#     166         res = (x,x1,None,None) if its is None else (x, y, its, outs.itemgot(slice(self.n_inp,None)))
#     167         if not show: return res
# --> 168         show_results(*res, ctxs=ctxs, max_n=max_n, **kwargs)
#     169
#     170     @property
#
# /usr/local/lib/python3.10/dist-packages/fastcore/dispatch.py in __call__(self, *args, **kwargs)
#     118         elif self.inst is not None: f = MethodType(f, self.inst)
#     119         elif self.owner is not None: f = MethodType(f, self.owner)
# --> 120         return f(*args, **kwargs)
#     121
#     122     def __get__(self, inst, owner):
#
# /usr/local/lib/python3.10/dist-packages/fastai/tabular/learner.py in show_results(x, y, samples, outs, ctxs, max_n, **kwargs)
#      51 def show_results(x:Tabular, y:Tabular, samples, outs, ctxs=None, max_n=10, **kwargs):
#      52     df = x.all_cols[:max_n]
# ---> 53     for n in x.y_names: df[n+'_pred'] = y[n][:max_n].values
#      54     display_df(df)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3978         else:
#    3979             # set column
# -> 3980             self._set_item(key, value)
#    3981
#    3982     def _setitem_slice(self, key: slice, value):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in _set_item(self, key, value)
#    4185                     value = np.tile(value, (len(existing_piece.columns), 1)).T
#    4186
# -> 4187         self._set_item_mgr(key, value)
#    4188
#    4189     def _set_value(
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in _set_item_mgr(self, key, value)
#    4150         # value exception to occur first
#    4151         if len(self):
# -> 4152             self._check_setitem_copy()
#    4153
#    4154     def _iset_item(self, loc: int, value) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _check_setitem_copy(self, t, force)
#    4209
#    4210         if value == "raise":
# -> 4211             raise SettingWithCopyError(t)
#    4212         elif value == "warn":
#    4213             warnings.warn(t, SettingWithCopyWarning, stacklevel=find_stack_level())
#
# SettingWithCopyError:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Or use the predict method on a row:
row, clas, probs = learn.predict(df.iloc[0])
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
row.show()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Gender</th>
#       <th>Polyuria</th>
#       <th>Polydipsia</th>
#       <th>sudden weight loss</th>
#       <th>weakness</th>
#       <th>Polyphagia</th>
#       <th>Genital thrush</th>
#       <th>visual blurring</th>
#       <th>Itching</th>
#       <th>Irritability</th>
#       <th>delayed healing</th>
#       <th>partial paresis</th>
#       <th>muscle stiffness</th>
#       <th>Alopecia</th>
#       <th>Obesity</th>
#       <th>Age</th>
#       <th>class</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Male</td>
#       <td>No</td>
#       <td>Yes</td>
#       <td>No</td>
#       <td>Yes</td>
#       <td>No</td>
#       <td>No</td>
#       <td>No</td>
#       <td>Yes</td>
#       <td>No</td>
#       <td>Yes</td>
#       <td>No</td>
#       <td>Yes</td>
#       <td>Yes</td>
#       <td>Yes</td>
#       <td>40.0</td>
#       <td>Positive</td>
#     </tr>
#   </tbody>
# </table>

# %%
clas, probs
# Out:
# (tensor(1), tensor([0.4570, 0.5430]))

# %%
#To get prediction on a new dataframe, you can use the test_dl method of the DataLoaders.
#That dataframe does not need to have the dependent variable in its column.
test_df=df.copy()
test_df.drop(['class'], axis=1, inplace=True)

dl=learn.dls.test_dl(test_df)

# %%
#Then Learner.get_preds will give you the predictions:
learn.get_preds(dl=dl)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# (tensor([[0.4570, 0.5430],
#          [0.4509, 0.5491],
#          [0.4560, 0.5440],
#          ...,
#          [0.4510, 0.5490],
#          [0.4669, 0.5331],
#          [0.4552, 0.5448]]),
#  None)

# %%
#training more cycles
learn_2 = tabular_learner(dls, metrics=accuracy)
learn_2.fit_one_cycle(16)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.692577</td>
#       <td>0.694703</td>
#       <td>0.500000</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.655800</td>
#       <td>0.687759</td>
#       <td>0.586538</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.599268</td>
#       <td>0.682109</td>
#       <td>0.576923</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.533315</td>
#       <td>0.673575</td>
#       <td>0.576923</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.469553</td>
#       <td>0.640436</td>
#       <td>0.586538</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.419938</td>
#       <td>0.618380</td>
#       <td>0.576923</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.374678</td>
#       <td>0.622223</td>
#       <td>0.615385</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.337231</td>
#       <td>0.561966</td>
#       <td>0.653846</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.304128</td>
#       <td>0.539534</td>
#       <td>0.682692</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.273681</td>
#       <td>0.485345</td>
#       <td>0.711538</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.248550</td>
#       <td>0.496899</td>
#       <td>0.721154</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.228465</td>
#       <td>0.360998</td>
#       <td>0.826923</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.209218</td>
#       <td>0.325434</td>
#       <td>0.875000</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.192087</td>
#       <td>0.286712</td>
#       <td>0.913462</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.178409</td>
#       <td>0.252444</td>
#       <td>0.913462</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.164892</td>
#       <td>0.235571</td>
#       <td>0.923077</td>
#       <td>00:00</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn_2.show_results()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Gender</th>
#       <th>Polyuria</th>
#       <th>Polydipsia</th>
#       <th>sudden weight loss</th>
#       <th>weakness</th>
#       <th>Polyphagia</th>
#       <th>Genital thrush</th>
#       <th>visual blurring</th>
#       <th>Itching</th>
#       <th>Irritability</th>
#       <th>delayed healing</th>
#       <th>partial paresis</th>
#       <th>muscle stiffness</th>
#       <th>Alopecia</th>
#       <th>Obesity</th>
#       <th>Age</th>
#       <th>class</th>
#       <th>class_pred</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1.0</td>
#       <td>2.0</td>
#       <td>2.0</td>
#       <td>2.0</td>
#       <td>2.0</td>
#       <td>2.0</td>
#       <td>1.0</td>
#       <td>2.0</td>
#       <td>2.0</td>
#       <td>2.0</td>
#       <td>2.0</td>
#       <td>2.0</td>
#       <td>2.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>-0.020172</td>
#       <td>1.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>2.0</td>
#       <td>2.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>2.0</td>
#       <td>2.0</td>
#       <td>2.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>2.0</td>
#       <td>2.0</td>
#       <td>1.0</td>
#       <td>3.435155</td>
#       <td>1.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1.0</td>
#       <td>2.0</td>
#       <td>2.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>2.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>2.0</td>
#       <td>1.0</td>
#       <td>-1.089678</td>
#       <td>1.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>2.0</td>
#       <td>1.0</td>
#       <td>2.0</td>
#       <td>1.0</td>
#       <td>2.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>2.0</td>
#       <td>1.0</td>
#       <td>-0.431520</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>1.0</td>
#       <td>2.0</td>
#       <td>2.0</td>
#       <td>1.0</td>
#       <td>2.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>2.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>-1.089678</td>
#       <td>1.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>-1.089678</td>
#       <td>1.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>2.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>2.0</td>
#       <td>2.0</td>
#       <td>1.0</td>
#       <td>2.0</td>
#       <td>2.0</td>
#       <td>2.0</td>
#       <td>2.0</td>
#       <td>1.0</td>
#       <td>2.0</td>
#       <td>2.0</td>
#       <td>1.0</td>
#       <td>1.296143</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>1.0</td>
#       <td>2.0</td>
#       <td>2.0</td>
#       <td>1.0</td>
#       <td>2.0</td>
#       <td>2.0</td>
#       <td>1.0</td>
#       <td>2.0</td>
#       <td>2.0</td>
#       <td>1.0</td>
#       <td>2.0</td>
#       <td>2.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>1.625222</td>
#       <td>1.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>2.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>2.0</td>
#       <td>1.0</td>
#       <td>2.0</td>
#       <td>1.0</td>
#       <td>2.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>2.0</td>
#       <td>1.0</td>
#       <td>-0.431520</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#   </tbody>
# </table>

# %%
#Or use the predict method on a row:
row, clas, probs = learn_2.predict(df.iloc[1])
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
row.show()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Gender</th>
#       <th>Polyuria</th>
#       <th>Polydipsia</th>
#       <th>sudden weight loss</th>
#       <th>weakness</th>
#       <th>Polyphagia</th>
#       <th>Genital thrush</th>
#       <th>visual blurring</th>
#       <th>Itching</th>
#       <th>Irritability</th>
#       <th>delayed healing</th>
#       <th>partial paresis</th>
#       <th>muscle stiffness</th>
#       <th>Alopecia</th>
#       <th>Obesity</th>
#       <th>Age</th>
#       <th>class</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Male</td>
#       <td>No</td>
#       <td>No</td>
#       <td>No</td>
#       <td>Yes</td>
#       <td>No</td>
#       <td>No</td>
#       <td>Yes</td>
#       <td>No</td>
#       <td>No</td>
#       <td>No</td>
#       <td>Yes</td>
#       <td>No</td>
#       <td>Yes</td>
#       <td>No</td>
#       <td>58.0</td>
#       <td>Positive</td>
#     </tr>
#   </tbody>
# </table>

# %%
to.xs[:3]
# Out:
#      Gender  Polyuria  Polydipsia  sudden weight loss  weakness  Polyphagia  \
# 116       1         2           2                   2         1           2
# 236       2         1           1                   1         2           2
# 417       1         2           2                   2         2           2
#
#      Genital thrush  visual blurring  Itching  Irritability  delayed healing  \
# 116               1                1        1             2                1
# 236               1                2        2             1                2
# 417               1                1        2             2                2
#
#      partial paresis  muscle stiffness  Alopecia  Obesity       Age
# 116                2                 2         1        1 -1.501026
# 236                1                 2         2        1  0.967064
# 417                2                 1         1        1 -0.760599

# %%
X_train, y_train = to.train.xs, to.train.ys.values.ravel()
X_test, y_test = to.valid.xs, to.valid.ys.values.ravel()

# %%
from sklearn.ensemble import RandomForestClassifier
rfc= RandomForestClassifier()
rfc
# Out:
# RandomForestClassifier()

# %%
from sklearn.metrics import accuracy_score
#training the model
rfc.fit(X_train, y_train)
rfc.score(X_test, y_test)
# rnf.score(X_train, y_train)
# Out:
# 0.9711538461538461

# %%
#testing the model
rfc_pred = rfc.predict(X_test)
accuracy_score(y_test, rfc_pred)
# Out:
# 0.9711538461538461
